# %%
import sys
sys.path.append('../')
from src.Society import Society
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
n = 1000
p = (0.32, 0.24, 0.27, 0.13)
_max = 2000
g = []
a = []
b = []
o = []
ab = []
af = []
bf = []
of = []
s = Society(n, p, _max)

print(s)
# Out:
# gen : 1
# population : 960
# femail portion 0.52, mail portion 0.48
# A : 0.33,B : 0.25,O : 0.28,AB : 0.14

# %%
for _ in range(1000):
    s.next_gen()
    f_p, m_p, a_p, b_p, o_p, ab_p = s.get_portion()
    af_p, bf_p, of_p = s.get_blood_featrue_portion()
    g.append(s.gen)
    a.append(a_p)
    b.append(b_p)
    o.append(o_p)
    ab.append(ab_p)
    af.append(af_p)
    bf.append(bf_p)
    of.append(of_p)
    if s.gen % 100 == 0:
        print(s)

plt.figure()
plt.title('Blood Type Proportion')
plt.xlabel('Generation')
plt.ylabel('Portion')
plt.plot(g, a, label='A')
plt.plot(g, b, label='B')
plt.plot(g, o, label='O')
plt.plot(g, ab, label='AB')
plt.legend()
plt.show()
plt.figure()
plt.title('ABO DNA pool Proportion')
plt.xlabel('Generation')
plt.ylabel('Portion')
plt.plot(g, af, label='A')
plt.plot(g, bf, label='B')
plt.plot(g, of, label='O')
plt.legend()
plt.show()
# Out:
# gen : 1100
# population : 1471
# femail portion 0.48, mail portion 0.52
# A : 0.75,B : 0.06,O : 0.06,AB : 0.13
# gen : 1200
# population : 2107
# femail portion 0.49, mail portion 0.51
# A : 0.68,B : 0.09,O : 0.11,AB : 0.11
# gen : 1300
# population : 1642
# femail portion 0.49, mail portion 0.51
# A : 0.66,B : 0.08,O : 0.15,AB : 0.11
# gen : 1400
# population : 1668
# femail portion 0.49, mail portion 0.51
# A : 0.56,B : 0.12,O : 0.22,AB : 0.10
# gen : 1500
# population : 1879
# femail portion 0.52, mail portion 0.48
# A : 0.41,B : 0.23,O : 0.25,AB : 0.11
# gen : 1600
# population : 1946
# femail portion 0.50, mail portion 0.50
# A : 0.46,B : 0.19,O : 0.23,AB : 0.12
# gen : 1700
# population : 2235
# femail portion 0.48, mail portion 0.52
# A : 0.60,B : 0.10,O : 0.23,AB : 0.07
# gen : 1800
# population : 2440
# femail portion 0.51, mail portion 0.49
# A : 0.54,B : 0.10,O : 0.31,AB : 0.05
# gen : 1900
# population : 1689
# femail portion 0.49, mail portion 0.51
# A : 0.58,B : 0.05,O : 0.33,AB : 0.04
# gen : 2000
# population : 2008
# femail portion 0.48, mail portion 0.52
# A : 0.59,B : 0.01,O : 0.39,AB : 0.01
