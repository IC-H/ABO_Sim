# %%
import sys
sys.path.append('../')
from src.Society import Society
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
n = 1000
p = (0.32, 0.24, 0.27, 0.13)
_max = 2000
g = []
a = []
b = []
o = []
ab = []
af = []
bf = []
of = []
s = Society(n, p, _max)

print(s)
# Out:
# gen : 1
# population : 960
# femail portion 0.50, mail portion 0.50
# A : 0.33,B : 0.25,O : 0.28,AB : 0.14

# %%
for _ in range(1000):
    s.next_gen()
    f_p, m_p, a_p, b_p, o_p, ab_p = s.get_portion()
    af_p, bf_p, of_p = s.get_blood_featrue_portion()
    g.append(s.gen)
    a.append(a_p)
    b.append(b_p)
    o.append(o_p)
    ab.append(ab_p)
    af.append(af_p)
    bf.append(bf_p)
    of.append(of_p)
    if s.gen % 100 == 0:
        print(s)

plt.figure()
plt.title('')
plt.plot(g, a, label='A')
plt.plot(g, b, label='B')
plt.plot(g, o, label='O')
plt.plot(g, ab, label='AB')
plt.legend()
plt.show()
plt.figure()
plt.plot(g, af, label='A')
plt.plot(g, bf, label='B')
plt.plot(g, of, label='O')
plt.legend()
plt.show()
# Out:
# gen : 2100
# population : 2087
# femail portion 0.50, mail portion 0.50
# A : 0.00,B : 0.15,O : 0.85,AB : 0.00
# gen : 2200
# population : 2072
# femail portion 0.50, mail portion 0.50
# A : 0.00,B : 0.08,O : 0.92,AB : 0.00
# gen : 2300
# population : 2045
# femail portion 0.51, mail portion 0.49
# A : 0.00,B : 0.07,O : 0.93,AB : 0.00
# gen : 2400
# population : 2146
# femail portion 0.51, mail portion 0.49
# A : 0.00,B : 0.09,O : 0.91,AB : 0.00
# gen : 2500
# population : 2101
# femail portion 0.50, mail portion 0.50
# A : 0.00,B : 0.21,O : 0.79,AB : 0.00
# gen : 2600
# population : 2104
# femail portion 0.48, mail portion 0.52
# A : 0.00,B : 0.15,O : 0.85,AB : 0.00
# gen : 2700
# population : 2090
# femail portion 0.49, mail portion 0.51
# A : 0.00,B : 0.18,O : 0.82,AB : 0.00
# gen : 2800
# population : 2035
# femail portion 0.51, mail portion 0.49
# A : 0.00,B : 0.25,O : 0.75,AB : 0.00
# gen : 2900
# population : 2066
# femail portion 0.51, mail portion 0.49
# A : 0.00,B : 0.18,O : 0.82,AB : 0.00
# gen : 3000
# population : 2146
# femail portion 0.52, mail portion 0.48
# A : 0.00,B : 0.09,O : 0.91,AB : 0.00
